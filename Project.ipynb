# %%
import pandas as pd
import numpy as np
import scipy as sp
import os
from sklearn.linear_model import LinearRegression, LogisticRegression
from sklearn.ensemble import RandomForestClassifier
import matplotlib
import matplotlib.pyplot as plt
from sklearn import datasets, linear_model

# %%
data_folder = './data/'

# %%
boston_pd = './data/Dept_11-00091/'
indianapolis_pd = './data/Dept_23-00089/'
minneapolis_pd = './data/Dept_24-00013/'
stpaul_pd = './data/Dept_24-00098/'
orlando_pd = './data/Dept_35-00016/'
charlotte_mecklenburg_pd = './data/Dept_35-00103/'
albuquerque_pd = './data/Dept_37-00027/'
epic_new_orleans_pd = './data/Dept_37-00049/'
seattle_pd = './data/Dept_49-00009/'
los_angeles_pd = './data/Dept_49-00033/'
oakland_pd = './data/Dept_49-00035/'
san_francisco_pd = './data/Dept_49-00081/'

# %%
for 
for filename in os.listdir(boston_pd):
    if "." in filename:
        f = pd.read_csv(boston_pd + filename)
    else:
        f1 = boston_pd + filename
f1
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (0,1,5,20,25,26,27,31,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# './data/Dept_11-00091/11-00091_Shapefiles'

# %%
police_departments = []
for filename in os.listdir(data_folder):
    if "." in filename:
        variable_descriptions = pd.read_csv(data_folder + filename)
    else:
        police_departments.append(data_folder + filename)

# %%
police_departments
# Out:
# ['./data/Dept_11-00091',
#  './data/Dept_23-00089',
#  './data/Dept_24-00013',
#  './data/Dept_24-00098',
#  './data/Dept_35-00016',
#  './data/Dept_35-00103',
#  './data/Dept_37-00027',
#  './data/Dept_37-00049',
#  './data/Dept_49-00009',
#  './data/Dept_49-00033',
#  './data/Dept_49-00035',
#  './data/Dept_49-00081']

# %%
f = []
f_dot = []
for i in range(len(police_departments)):
    for filename in os.listdir(police_departments[i]):
        if "." not in filename:
            f.append(police_departments[i] + '/' + filename + '/')
        else:
            f_dot.append(filename)
f
for i in range(len(f)):
    for j in os.listdir(f[i]):
        print(j)
        
f_dot
# Out:
# 11-00091_ACS_education-attainment
# 11-00091_ACS_education-attainment-over-25
# 11-00091_ACS_employment
# 11-00091_ACS_income
# 11-00091_ACS_owner-occupied-housing
# 11-00091_ACS_poverty
# 11-00091_ACS_race-age-sex
# 11-00091_ACS_race-sex-age
# boston_police_districts_f55.cst
# boston_police_districts_f55.dbf
# boston_police_districts_f55.prj
# boston_police_districts_f55.shp
# boston_police_districts_f55.shx
# 23-00089_ACS_education-attainment
# 23-00089_ACS_education-attainment-over-25
# 23-00089_ACS_employment
# 23-00089_ACS_income
# 23-00089_ACS_owner-occupied-housing
# 23-00089_ACS_poverty
# 23-00089_ACS_race-sex-age
# Indianapolis_Police_Zones.cpg
# Indianapolis_Police_Zones.dbf
# Indianapolis_Police_Zones.prj
# Indianapolis_Police_Zones.shp
# Indianapolis_Police_Zones.shx
# 24-00013_ACS_education-attainment
# 24-00013_ACS_education-attainment-over-25
# 24-00013_ACS_employment
# 24-00013_ACS_income
# 24-00013_ACS_owner-occupied-housing
# 24-00013_ACS_poverty
# ...

# %%
f
# Out:
# ['./data/Dept_11-00091/11-00091_ACS_data/',
#  './data/Dept_11-00091/11-00091_Shapefiles/',
#  './data/Dept_23-00089/23-00089_ACS_data/',
#  './data/Dept_23-00089/23-00089_Shapefiles/',
#  './data/Dept_24-00013/24-00013_ACS_data/',
#  './data/Dept_24-00013/24-00013_Shapefiles/',
#  './data/Dept_24-00098/24-00098_ACS_data/',
#  './data/Dept_24-00098/24-00098_Shapefiles/',
#  './data/Dept_35-00016/35-00016_ACS_data/',
#  './data/Dept_35-00016/35-00016_Shapefiles/',
#  './data/Dept_35-00103/35-00103_ACS_data/',
#  './data/Dept_35-00103/35-00103_Shapefiles/',
#  './data/Dept_37-00027/37-00027_ACS_data/',
#  './data/Dept_37-00027/37-00027_Shapefiles/',
#  './data/Dept_37-00049/37-00049_ACS_data/',
#  './data/Dept_37-00049/37-00049_Shapefiles/',
#  './data/Dept_49-00009/49-00009_ACS_data/',
#  './data/Dept_49-00009/49-00009_Shapefiles/',
#  './data/Dept_49-00033/49-00033_ACS_data/',
#  './data/Dept_49-00033/49-00033_Shapefiles/',
#  './data/Dept_49-00035/49-00035_ACS_data/',
# ...

# %%
f_dot
# Out:
# ['11-00091_Field-Interviews_2011-2015.csv',
#  '23-00089_UOF-P.csv',
#  '24-00013_UOF_2008-2017_prepped.csv',
#  '24-00098_Vehicle-Stops-data.csv',
#  '35-00016_UOF-OIS-P.csv',
#  '35-00103_UOF-OIS-P_prepped.csv',
#  '37-00027_UOF-P_2014-2016_prepped.csv',
#  '37-00049_UOF-P_2016_prepped.csv',
#  '49-00009_UOF.csv',
#  '49-0009_UOF.csv',
#  '49-00033_Arrests_2015.csv',
#  '49-00035_Incidents_2016.csv',
#  '49-00081_Incident-Reports_2012_to_May_2015.csv']

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-56-6dedbecb0502> in <module>()
#       5             files.append(filename)
#       6 files
# ----> 7 for i in os.listdir(files[1]):
#       8     print(i)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '11-00091_Shapefiles'

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-59-8eacf9230d7c> in <module>()
#       1 for i in range(len(files)):
# ----> 2     for f in os.listdir(files[i]):
#       3         print(f)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: '11-00091_ACS_data'

# %%
la_arrests = pd.read_csv(los_angeles_pd + '49-00033_Arrests_2015.csv')
# Out:
# C:\Users\PC\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (1,2,3,5,6,9,16,17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
la_arrests
# Out:
#         INCIDENT_DATE INCIDENT_TIME INCIDENT_UNIQUE_IDENTIFIER  \
# 0           ARST DATE          TIME                     RPT_ID
# 1       12/31/15 0:00          2345                    4538991
# 2       12/31/15 0:00          2330                    4538996
# 3       12/31/15 0:00          2320                    4539142
# 4       12/31/15 0:00          2319                    4538947
# 5       12/31/15 0:00          2316                    4538938
# 6       12/31/15 0:00          2315                    4539107
# 7       12/31/15 0:00          2310                    4538978
# 8       12/31/15 0:00          2310                    4538979
# 9       12/31/15 0:00          2310                    4538936
# 10      12/31/15 0:00          2310                    4539025
# 11      12/31/15 0:00          2310                    4539040
# 12      12/31/15 0:00          2300                    4538983
# 13      12/31/15 0:00          2300                    4539058
# ...
